# %% [markdown]
# LangChain ReAct Agent Demo

# %%
import getpass
import os


def _set_env(var: str):
    if not os.environ.get(var):
        os.environ[var] = getpass.getpass(f"{var}: ")

_set_env("OPENAI_API_KEY")

# %%
# First we initialize the model we want to use.
from langchain_openai import ChatOpenAI

model = ChatOpenAI(model="gpt-4o", temperature=0)


# For this tutorial we will use custom tool that returns pre-defined values for weather in two cities (NYC & SF)

from typing import Literal

from langchain_core.tools import tool

# %%
import os
import shutil
from typing import List, Dict, Optional

@tool
def list_files(directory: str) -> List[Dict[str, Optional[str]]]:
    """
    Lists all files in the specified directory, including their name, type, and metadata.
    """
    files = []
    for entry in os.scandir(directory):
        file_info = {
            "name": entry.name,
            "type": "directory" if entry.is_dir() else "file",
            "size": os.path.getsize(entry) if not entry.is_dir() else None,
            "created": os.path.getctime(entry),
            "modified": os.path.getmtime(entry),
        }
        files.append(file_info)
    return files


@tool
def create_folder(directory: str, folder_name: str) -> str:
    """
    Creates a new folder in the specified directory.
    """
    new_folder_path = os.path.join(directory, folder_name)
    os.makedirs(new_folder_path, exist_ok=True)
    return new_folder_path


@tool
def rename_item(old_path: str, new_name: str) -> str:
    """
    Renames a file or folder to the specified new name.
    """
    new_path = os.path.join(os.path.dirname(old_path), new_name)
    os.rename(old_path, new_path)
    return new_path


@tool
def change_directory(new_directory: str) -> str:
    """
    Changes the working directory to the specified path.
    """
    os.chdir(new_directory)
    return os.getcwd()


@tool
def move_item(src_path: str, dest_directory: str) -> str:
    """
    Moves a file or folder to the specified destination directory.
    """
    dest_path = os.path.join(dest_directory, os.path.basename(src_path))
    shutil.move(src_path, dest_path)
    return dest_path

# %%
tools = [list_files, create_folder, rename_item, change_directory, move_item]

# Define the graph

from langgraph.prebuilt import create_react_agent

graph = create_react_agent(model, tools=tools)

# %%
def print_stream(stream):
    for s in stream:
        message = s["messages"][-1]
        if isinstance(message, tuple):
            print(message)
        else:
            message.pretty_print()

# %%
inputs = {"messages": [("user", "There is a folder called 'downloads' in this directory. Use your tools to sort the files into folders based on categories you determine. If you don't know what to do with a file, don't delete it - just move it to a 'miscellaneous' folder. Keep all your sub-folders within downloads.")]}
print_stream(graph.stream(inputs, stream_mode="values"))
# Out:
# ================================ Human Message =================================
#
# There is a folder called 'downloads' in this directory. Use your tools to sort the files into folders based on categories you determine. If you don't know what to do with a file, don't delete it - just move it to a 'miscellaneous' folder. Keep all your sub-folders within downloads.
# ================================== Ai Message ==================================
# Tool Calls:
#   list_files (call_a5lCo5FL6jv7EvE64sa4DSgQ)
#  Call ID: call_a5lCo5FL6jv7EvE64sa4DSgQ
#   Args:
#     directory: downloads
# ================================= Tool Message =================================
# Name: list_files
#
# [{"name": "egl47_resume.pdf", "type": "file", "size": 104028, "created": 1730693269.0491664, "modified": 1727670988.9579325}, {"name": "error_3350.txt", "type": "file", "size": 79930, "created": 1730693269.0667443, "modified": 1725418037.151453}, {"name": "Everett_Lee_Resume.pdf", "type": "file", "size": 64316, "created": 1730693269.0815275, "modified": 1724438414.8603864}, {"name": "Everett_Lee_Resume_2.pdf", "type": "file", "size": 64131, "created": 1730693269.097652, "modified": 1727809009.1513162}, {"name": "Everett_Lee_transcript.pdf", "type": "file", "size": 9574, "created": 1730693269.1132874, "modified": 1727191962.6984296}, {"name": "fabric-api-0.85.0+1.19.4.jar", "type": "file", "size": 1992606, "created": 1730693269.1425095, "modified": 1704965969.4775877}, {"name": "failure_message.png", "type": "file", "size": 108369, "created": 1730693269.1664824, "modified": 1725639565.0193427}, {"name": "fuck-nuance.pdf", "type": "file", "size": 201670, "created": 1730693269.189513, "modified": 1724965176.9874797}, {"name": "generate_docs.ipynb", "type": "file", "size": 88315, "created": 1730693269.2277765, "modified": 1725743337.3045745}, {"name": "generator.keras", "type": "file", "size": 24752074, "created": 1730693269.2796593, "modified": 1714343404.7511778}, {"name": "imagenames.txt", "type": "file", "size": 271531, "created": 1730693269.3967812, "modified": 1714155355.4683006}, {"name": "info-3350-packages.txt", "type": "file", "size": 223, "created": 1730693269.4116416, "modified": 1725647400.9991317}, {"name": "InquisitPlayer.lnk", "type": "file", "size": 1296, "created": 1730693269.4267483, "modified": 1715138263.9036584}, {"name": "Master of Engineering Program _ Department of Computer Science.pdf", "type": "file", "size": 296583, "created": 1730693269.4417825, "modified": 1725479139.4576185}, {"name": "MLE People.txt", "type": "file", "size": 265, "created": 1730693269.4594023, "modified": 1725575588.3353267}, {"name": "MLE_APPS.csv", "type": "file", "size": 323665, "created": 1730693269.4877918, "modified": 1725741761.0}, {"name": "New Text Document.txt", "type": "file", "size": 2402, "created": 1730693269.5047984, "modified": 1728169689.7891037}, {"name": "Notion.lnk", "type": "file", "size": 2221, "created": 1730693269.5206902, "modified": 1669587826.301914}, {"name": "Palantir Technologies - Forward Deployed AI Engineer.pdf", "type": "file", "size": 169370, "created": 1730693269.5397367, "modified": 1725479082.2560241}, {"name": "Project Report Individual.pdf", "type": "file", "size": 70470, "created": 1730693269.5559075, "modified": 1716006727.2649455}, {"name": "PUNKPODCAST.flp", "type": "file", "size": 127407, "created": 1730693269.5734882, "modified": 1730060610.3756227}, {"name": "PUNKPODCAST_DEMOTAPE.mp3", "type": "file", "size": 6236230, "created": 1730693269.5886075, "modified": 1730002394.2959063}, {"name": "RAGE AGAINST THE LATRINE.mp3", "type": "file", "size": 6425565, "created": 1730693269.6116924, "modified": 1730057926.9671497}, {"name": "sample-recommendation-letter.pdf", "type": "file", "size": 51667, "created": 1730693269.638475, "modified": 1725415975.179071}, {"name": "Sentiment Symposium Tutorial_ Tokenizing.pdf", "type": "file", "size": 508755, "created": 1730693269.6576202, "modified": 1724965832.6639807}, {"name": "Slack.lnk", "type": "file", "size": 2211, "created": 1730693269.6725645, "modified": 1729626885.7117352}, {"name": "stereo_photometric_stereo_student.zip", "type": "file", "size": 2919688, "created": 1730693269.6919208, "modified": 1710780554.9109168}, {"name": "Syllabus-FA24-NBA5380-LEC001-PRIOR-TERM.pdf", "type": "file", "size": 153575, "created": 1730693269.7225032, "modified": 1718143201.0632634}, {"name": "Unit 2_ Punk Podcast Writeup.pdf", "type": "file", "size": 255473, "created": 1730693269.7426891, "modified": 1730078148.2864685}, {"name": "Visual Studio Code.lnk", "type": "file", "size": 1418, "created": 1730693269.7630503, "modified": 1668443177.5308893}, {"name": "W2. ...
# ================================== Ai Message ==================================
# Tool Calls:
#   create_folder (call_X6sk4jXjbeSsbBFvGSZlIKCU)
#  Call ID: call_X6sk4jXjbeSsbBFvGSZlIKCU
#   Args:
#     directory: downloads
#     folder_name: resumes
#   create_folder (call_Aq0xDx1X63O0RT3XXQxXnBca)
#  Call ID: call_Aq0xDx1X63O0RT3XXQxXnBca
#   Args:
#     directory: downloads
#     folder_name: text_files
#   create_folder (call_qXdkU1eBn0eREwy9J5OF5nmt)
#  Call ID: call_qXdkU1eBn0eREwy9J5OF5nmt
#   Args:
#     directory: downloads
#     folder_name: pdfs
#   create_folder (call_ZyLM98eZfQHn6MLtGGP8LfI6)
#  Call ID: call_ZyLM98eZfQHn6MLtGGP8LfI6
#   Args:
#     directory: downloads
#     folder_name: images
#   create_folder (call_tw18hy1RQ0HFuo549CUluU9P)
#  Call ID: call_tw18hy1RQ0HFuo549CUluU9P
#   Args:
#     directory: downloads
#     folder_name: audio
#   create_folder (call_MaeJ4VIiQprN1838KNgmEBIc)
#  Call ID: call_MaeJ4VIiQprN1838KNgmEBIc
#   Args:
#     directory: downloads
#     folder_name: software
#   create_folder (call_a4SdJUFXsVKUh7hq5nySAyTd)
#  Call ID: call_a4SdJUFXsVKUh7hq5nySAyTd
#   Args:
#     directory: downloads
#     folder_name: miscellaneous
# ================================= Tool Message =================================
# Name: create_folder
#
# downloads\miscellaneous
# ================================== Ai Message ==================================
# Tool Calls:
#   move_item (call_tEDCFJl9IfpLC5lUSPzRGJqL)
#  Call ID: call_tEDCFJl9IfpLC5lUSPzRGJqL
#   Args:
#     src_path: downloads/egl47_resume.pdf
#     dest_directory: downloads/resumes
#   move_item (call_IEUPd2DVKOkVZ7Jz4bVja5C0)
#  Call ID: call_IEUPd2DVKOkVZ7Jz4bVja5C0
#   Args:
#     src_path: downloads/Everett_Lee_Resume.pdf
#     dest_directory: downloads/resumes
#   move_item (call_fr1wXj3vNUxBDHTLlRZ6T09m)
#  Call ID: call_fr1wXj3vNUxBDHTLlRZ6T09m
#   Args:
#     src_path: downloads/Everett_Lee_Resume_2.pdf
#     dest_directory: downloads/resumes
#   move_item (call_4g3XjudPRa9l333S4P1TXhza)
#  Call ID: call_4g3XjudPRa9l333S4P1TXhza
#   Args:
#     src_path: downloads/Everett_Lee_transcript.pdf
#     dest_directory: downloads/resumes
#   move_item (call_ENYPKF6lNuSOISGanbw6gT0d)
#  Call ID: call_ENYPKF6lNuSOISGanbw6gT0d
#   Args:
#     src_path: downloads/fuck-nuance.pdf
#     dest_directory: downloads/pdfs
#   move_item (call_RIJFL56WmLisRo4iIF8yDB5E)
#  Call ID: call_RIJFL56WmLisRo4iIF8yDB5E
#   Args:
#     src_path: downloads/Master of Engineering Program _ Department of Computer Science.pdf
#     dest_directory: downloads/pdfs
#   move_item (call_EUraL9iqbLhJsdPAVxHGQkVF)
#  Call ID: call_EUraL9iqbLhJsdPAVxHGQkVF
#   Args:
#     src_path: downloads/Palantir Technologies - Forward Deployed AI Engineer.pdf
#     dest_directory: downloads/pdfs
#   move_item (call_0v20rZgR1DTJJImC675mZeMM)
#  Call ID: call_0v20rZgR1DTJJImC675mZeMM
#   Args:
#     src_path: downloads/Project Report Individual.pdf
#     dest_directory: downloads/pdfs
#   move_item (call_fZzEkKdiMsgROu52bKG51A8V)
#  Call ID: call_fZzEkKdiMsgROu52bKG51A8V
#   Args:
#     src_path: downloads/sample-recommendation-letter.pdf
#     dest_directory: downloads/pdfs
#   move_item (call_uV47HFuHzau40DJhOHvftzi3)
#  Call ID: call_uV47HFuHzau40DJhOHvftzi3
#   Args:
#     src_path: downloads/Sentiment Symposium Tutorial_ Tokenizing.pdf
#     dest_directory: downloads/pdfs
#   move_item (call_Fe2TQjOSzgfuye2DJr3G0zZo)
#  Call ID: call_Fe2TQjOSzgfuye2DJr3G0zZo
#   Args:
#     src_path: downloads/Syllabus-FA24-NBA5380-LEC001-PRIOR-TERM.pdf
#     dest_directory: downloads/pdfs
#   move_item (call_CN4h8kEAukaeoH9HZ8nfW8yD)
#  Call ID: call_CN4h8kEAukaeoH9HZ8nfW8yD
#   Args:
#     src_path: downloads/Unit 2_ Punk Podcast Writeup.pdf
#     dest_directory: downloads/pdfs
#   move_item (call_o8qiG4GeW1dsDNzm2WdqfRZg)
#  Call ID: call_o8qiG4GeW1dsDNzm2WdqfRZg
#   Args:
#     src_path: downloads/W2.pdf
#     dest_directory: downloads/pdfs
# ================================= Tool Message =================================
# Name: move_item
#
# downloads/pdfs\W2.pdf
# ================================== Ai Message ==================================
# Tool Calls:
#   move_item (call_X1HnJduB6Puk47AVbClqZxHy)
#  Call ID: call_X1HnJduB6Puk47AVbClqZxHy
#   Args:
#     src_path: downloads/error_3350.txt
#     dest_directory: downloads/text_files
#   move_item (call_Nzhz5mx8CAxDWJWFDxlcd3NP)
#  Call ID: call_Nzhz5mx8CAxDWJWFDxlcd3NP
#   Args:
#     src_path: downloads/generate_docs.ipynb
#     dest_directory: downloads/miscellaneous
#   move_item (call_qnrA0LPgc0unm82mpts6fXco)
#  Call ID: call_qnrA0LPgc0unm82mpts6fXco
#   Args:
#     src_path: downloads/imagenames.txt
#     dest_directory: downloads/text_files
#   move_item (call_J5QASG9Lh42WWC8rsPa1OcT3)
#  Call ID: call_J5QASG9Lh42WWC8rsPa1OcT3
#   Args:
#     src_path: downloads/info-3350-packages.txt
#     dest_directory: downloads/text_files
#   move_item (call_VOMf5db60kaxEEDiMqogBvX5)
#  Call ID: call_VOMf5db60kaxEEDiMqogBvX5
#   Args:
#     src_path: downloads/MLE People.txt
#     dest_directory: downloads/text_files
#   move_item (call_7WRxiHwHGyJRTFnqrnykmKpN)
#  Call ID: call_7WRxiHwHGyJRTFnqrnykmKpN
#   Args:
#     src_path: downloads/MLE_APPS.csv
#     dest_directory: downloads/miscellaneous
#   move_item (call_ydAIYTpWIK1Z1NnmlSjoDeF1)
#  Call ID: call_ydAIYTpWIK1Z1NnmlSjoDeF1
#   Args:
#     src_path: downloads/New Text Document.txt
#     dest_directory: downloads/text_files
#   move_item (call_Xtklf5hFehHx76YcQYMhzLNd)
#  Call ID: call_Xtklf5hFehHx76YcQYMhzLNd
#   Args:
#     src_path: downloads/fabric-api-0.85.0+1.19.4.jar
#     dest_directory: downloads/software
#   move_item (call_JH0IGek2WbsTG7Ij23u2Syub)
#  Call ID: call_JH0IGek2WbsTG7Ij23u2Syub
#   Args:
#     src_path: downloads/generator.keras
#     dest_directory: downloads/miscellaneous
#   move_item (call_dNTzidYwgvyoFar1WFyCCl4Q)
#  Call ID: call_dNTzidYwgvyoFar1WFyCCl4Q
#   Args:
#     src_path: downloads/InquisitPlayer.lnk
#     dest_directory: downloads/miscellaneous
#   move_item (call_IWN7OCRhKmTNYUuOfXjabl15)
#  Call ID: call_IWN7OCRhKmTNYUuOfXjabl15
#   Args:
#     src_path: downloads/Notion.lnk
#     dest_directory: downloads/miscellaneous
#   move_item (call_j9TmGjuuVQun6FkFRP6m7pkU)
#  Call ID: call_j9TmGjuuVQun6FkFRP6m7pkU
#   Args:
#     src_path: downloads/Slack.lnk
#     dest_directory: downloads/miscellaneous
#   move_item (call_0vH7HcVIrC2XsSWkS5IxthHq)
#  Call ID: call_0vH7HcVIrC2XsSWkS5IxthHq
#   Args:
#     src_path: downloads/Visual Studio Code.lnk
#     dest_directory: downloads/miscellaneous
# ================================= Tool Message =================================
# Name: move_item
#
# downloads/miscellaneous\Visual Studio Code.lnk
# ================================== Ai Message ==================================
# Tool Calls:
#   move_item (call_uuaa8sNMYCJXiTPaHGflArKA)
#  Call ID: call_uuaa8sNMYCJXiTPaHGflArKA
#   Args:
#     src_path: downloads/failure_message.png
#     dest_directory: downloads/images
#   move_item (call_NLVP20ONBvNsfxrx1DNhGf9l)
#  Call ID: call_NLVP20ONBvNsfxrx1DNhGf9l
#   Args:
#     src_path: downloads/Zoom_BG_07.png
#     dest_directory: downloads/images
#   move_item (call_HfuiC1oyny9Acub5a1Jdpq0b)
#  Call ID: call_HfuiC1oyny9Acub5a1Jdpq0b
#   Args:
#     src_path: downloads/PUNKPODCAST.flp
#     dest_directory: downloads/miscellaneous
#   move_item (call_HKuGXRt1eoH9GB9Ssj8Jp6uK)
#  Call ID: call_HKuGXRt1eoH9GB9Ssj8Jp6uK
#   Args:
#     src_path: downloads/PUNKPODCAST_DEMOTAPE.mp3
#     dest_directory: downloads/audio
#   move_item (call_FqS9jl5BhfmWLugv1uL6l4hW)
#  Call ID: call_FqS9jl5BhfmWLugv1uL6l4hW
#   Args:
#     src_path: downloads/RAGE AGAINST THE LATRINE.mp3
#     dest_directory: downloads/audio
#   move_item (call_Z60cFYb31yfggNmbMeOf7LMy)
#  Call ID: call_Z60cFYb31yfggNmbMeOf7LMy
#   Args:
#     src_path: downloads/stereo_photometric_stereo_student.zip
#     dest_directory: downloads/miscellaneous
#   move_item (call_tIhifoKwt2KpaPkZa3HqEPgx)
#  Call ID: call_tIhifoKwt2KpaPkZa3HqEPgx
#   Args:
#     src_path: downloads/Wurst-Client-v7.35.2-MC1.19.4.jar
#     dest_directory: downloads/software
# ================================= Tool Message =================================
# Name: move_item
#
# downloads/software\Wurst-Client-v7.35.2-MC1.19.4.jar
# ================================== Ai Message ==================================
#
# The files in the 'downloads' folder have been sorted into the following categories:
#
# - **Resumes**: Contains resume-related PDF files.
# - **Text Files**: Contains text files and similar documents.
# - **PDFs**: Contains various PDF documents.
# - **Images**: Contains image files.
# - **Audio**: Contains audio files.
# - **Software**: Contains software-related files, such as .jar files.
# - **Miscellaneous**: Contains files that didn't fit into the other categories, including shortcuts, notebooks, and other file types.
#
# If you need further assistance or adjustments, feel free to ask!
